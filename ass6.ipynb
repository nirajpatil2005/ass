# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("temperatures.csv")

# %%
df.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %%
df.isnull().sum()
# Out:
# YEAR       0
# JAN        0
# FEB        0
# MAR        0
# APR        0
# MAY        0
# JUN        0
# JUL        0
# AUG        0
# SEP        0
# OCT        0
# NOV        0
# DEC        0
# ANNUAL     0
# JAN-FEB    0
# MAR-MAY    0
# JUN-SEP    0
# OCT-DEC    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
X = df["YEAR"].values[:, None] # convert pandas series into numpy array
y = df["ANNUAL"]

# %%
Z=df[['YEAR']].values #another way for converting pandas series to numpy array
Z
# Out:
# array([[1901],
#        [1902],
#        [1903],
#        [1904],
#        [1905],
#        [1906],
#        [1907],
#        [1908],
#        [1909],
#        [1910],
#        [1911],
#        [1912],
#        [1913],
#        [1914],
#        [1915],
#        [1916],
#        [1917],
#        [1918],
#        [1919],
#        [1920],
#        [1921],
#        [1922],
#        [1923],
#        [1924],
#        [1925],
#        [1926],
#        [1927],
#        [1928],
#        [1929],
#        [1930],
#        [1931],
#        [1932],
#        [1933],
#        [1934],
#        [1935],
#        [1936],
#        [1937],
#        [1938],
#        [1939],
#        [1940],
#        [1941],
#        [1942],
#        [1943],
#        [1944],
#        [1945],
#        [1946],
#        [1947],
#        [1948],
#        [1949],
#        [1950],
#        [1951],
#        [1952],
#        [1953],
#        [1954],
#        [1955],
#        [1956],
#        [1957],
#        [1958],
#        [1959],
#        [1960],
#        [1961],
#        [1962],
#        [1963],
#        [1964],
#        [1965],
#        [1966],
#        [1967],
#        [1968],
#        [1969],
#        [1970],
#        [1971],
#        [1972],
#        [1973],
#        [1974],
#        [1975],
#        [1976],
#        [1977],
#        [1978],
#        [1979],
#        [1980],
#        [1981],
#        [1982],
#        [1983],
#        [1984],
#        [1985],
#        [1986],
#        [1987],
#        [1988],
#        [1989],
#        [1990],
#        [1991],
#        [1992],
#        [1993],
#        [1994],
#        [1995],
#        [1996],
#        [1997],
#        [1998],
#        [1999],
#        [2000],
#        [2001],
#        [2002],
#        [2003],
#        [2004],
#        [2005],
#        [2006],
#        [2007],
#        [2008],
#        [2009],
#        [2010],
#        [2011],
#        [2012],
#        [2013],
#        [2014],
#        [2015],
#        [2016],
#        [2017]], dtype=int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 2)

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([28.71795319, 29.71478059, 28.77183575, 29.14901369, 28.4215991 ,
#        29.10860177, 29.00083664, 29.45883842, 29.21636689, 28.79877703,
#        28.987366  , 28.73142383, 29.83601636, 29.75519252, 28.56977614,
#        28.58324679, 29.55313291, 29.63395675, 28.46201102, 29.37801458,
#        28.94695408, 29.20289625, 28.78530639, 28.54283486])

# %%
print("Mean absolute error: ", metrics.mean_absolute_error(y_test, y_pred))
print("Mean squared error: ", metrics.mean_squared_error(y_test, y_pred))
print("R2 score: ", metrics.r2_score(y_test, y_pred))
# Out:
# Mean absolute error:  0.20544880638046958
# Mean squared error:  0.06787195645553983
# R2 score:  0.666554248618334

# %%
plt.scatter(X_train, y_train, color="green", label = "Actual")
plt.plot(X_test, y_pred, color = "orange", label = "Predicted")
plt.xlabel("YEAR")
plt.ylabel("Annual temperature")
plt.legend()
plt.show()

# %%
j=0
for i in df.columns:
    print(i,y_pred[j])
    j+=1
# Out:
# YEAR 28.717953191133326
# JAN 29.714780593745253
# FEB 28.771835753436676
# MAR 29.149013689560107
# APR 28.421599098464917
# MAY 29.108601767832596
# JUN 29.000836643225902
# JUL 29.45883842280435
# AUG 29.21636689243929
# SEP 28.798777034588348
# OCT 28.987366002650063
# NOV 28.731423831709165
# DEC 29.836016358927782
# ANNUAL 29.755192515472764
# JAN-FEB 28.56977614479912
# MAR-MAY 28.58324678537496
# JUN-SEP 29.55313290683521
# OCT-DEC 29.63395675029023
